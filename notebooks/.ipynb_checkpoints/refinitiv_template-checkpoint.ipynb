# %%
# Imports
import refinitiv.dataplatform.eikon as ek
import pandas as pd
import time

# %%
# Utils
def get_ric(symbol):
    """
    symbol: the symbol of the company name in your portfolio.  
    Find the best possible RIC match for company names.
    returns: ric if there is a match, or initial company name. 
    """
    possible_rics = ek.json_requests.send_json_request('SymbologySearch',{'symbols': [symbol], 'from': 'ticker', 'to': ['RIC'], 'bestMatchOnly': False})
    try:
        return possible_rics.json().get("mappedSymbols")[0].get("RICs")[0]
    except:
        return symbol
    
def get_isin_from_ric(ric):
    """ 
    Find the ISIN match for your input RIC.
    """
    isin = ek.get_symbology(ric, from_symbol_type="RIC", to_symbol_type="ISIN")
    try:
        return isin.ISIN[0]
    except:
        return "N/A"
    

def get_isin_from_sedol(sedol):
    """ 
    Find the ISIN match for your input sedol.
    """
    isin = ek.get_symbology(sedol, from_symbol_type="SEDOL", to_symbol_type="ISIN")
    try:
        return isin.ISIN[0]
    except:
        return "N/A"
    
def format_df(esg_df, esg_df_bis, year):
    test = esg_df_bis[esg_df_bis.year == year].copy().drop(columns=["year"])
    test.columns = ["Instrument", "Environmental Pillar Score Grade "+str(year), "Environmental Pillar Score "+str(year)]
    return pd.merge(esg_df, test, how="left", left_on="Instrument", right_on="Instrument")

# %% [markdown]
# Set the API key :

# %%
app_key = "213f70312b3740cfa9f65def2171d679808d0131"#"467e1d8d1e624dfc834b60e91bba50e474bea063"
ek.set_app_key(app_key)

# %% [markdown]
# #### First, we get the Reuters Index Codes from the portfolio company symbols.

# %%
input_path = "data/" #"../inputs/"
output_path = "output/"
filename = "allocation210420.csv"
#portfolio = pd.read_excel(input_path+filename)#.drop(columns=["Unnamed: 0"])#header=None)
portfolio = pd.read_csv(input_path+filename, sep=";")

# %%
portfolio = portfolio[portfolio.Sleeve=="equity"].copy()

# %% [markdown]
# Now, get the rics from the symbols using the eikon api :

# %%
#rics = [get_ric(symbol) for symbol in symbols]
#isins = [get_isin_from_ric(ric) for ric in rics]
isins = list(portfolio.ISIN)

# %%
#sedols = portfolio.loc[:,"SEDOL"]

# %%
#isins = [get_isin_from_sedol(sedol) for sedol in sedols]

# %% [markdown]
# #### Next, we retrieve the corresponding ESG data.

# %% [markdown]
# Find the field names you are interested in by looking at the Data Item Browser (type it in the search bar).

# %%
help(ek.get_data)
# Out:
# Help on function get_data in module refinitiv.dataplatform.legacy.data_grid:
#
# get_data(instruments, fields, parameters=None, field_name=False, raw_output=False, debug=False, raw_response=False)
#     Returns a pandas.DataFrame with fields in columns and instruments as row index
#
#     Parameters
#     ----------
#     instruments: string or list
#         Single instrument or list of instruments to request.
#
#     fields: string, dictionary or list of strings and/or dictionaries.
#         List of fields to request.
#
#         Examples:
#
#         - 'TR.PriceClose'
#         - {'TR.GrossProfit': { 'params':{ 'Scale': 6, 'Curn': 'EUR' }}
#         - {'TR.GrossProfit': { 'params':{ 'Scale': 6, 'Curn': 'EUR' },sort_dir:'desc'}
#         - ['TR.PriceClose','TR.PriceOpen']
#         - [{'TR.PriceClose':  {'sort_dir':asc,sort_priority:1}},{'TR.PriceOpen':  {'sort_dir':asc,sort_priority:0}}
#
#         You can use the legacy TR_Field to build the fields:
#
#         >>> fields = [ek.TR_Field('tr.revenue'),ek.TR_Field('tr.open','asc',1),ek.TR_Field('TR.GrossProfit',{'Scale': 6, 'Curn': 'EUR'},'asc',0)]
#         >>> data, err = ek.get_data(["IBM","MSFT.O"],fields)
#
#         Tips:
#         You can launch the Data Item Browser to discover fields and parameters,
#         or copy field names and parameters from TR Eikon - MS Office formulas
#
#     parameters: string or dictionary, optional
#         Single global parameter key=value or dictionary of global parameters to request.
#
#         Default: None
#
#     field_name: boolean, optional
#         Define if column headers are filled with field name or display names.
#
#         If True value, field names will ube used as column headers. Otherwise, the full display name will be used.
#
#         Default: False
#
#     raw_output: boolean, optional
#         By default the output is a pandas.DataFrame.
#
#         Set raw_output=True to get data in Json format.
#
#         Default: False
#
#     debug: boolean, optional
#         When set to True, the json request and response are printed. Default value is False
#
#     Returns
#     -------
#     pandas.DataFrame
#         Returns pandas.DataFrame with fields in columns and instruments as row index
#
#         errors
#             Returns a list of errors
#
#     Raises
#     ----------
#         Exception
#             If http request fails or if server returns an error.
#
#         ValueError
#             If a parameter type or value is wrong.
#
#     Examples
#     --------
#     >>> import eikon as ek
#     >>> ek.set_app_key('set your app key here')
#     >>> data, err = ek.get_data(["IBM", "GOOG.O", "MSFT.O"], ["TR.PriceClose", "TR.Volume", "TR.PriceLow"])
#     >>> data, err = ek.get_data("IBM", ['TR.Employees', {'TR.GrossProfit':{'params':{'Scale': 6, 'Curn': 'EUR'},'sort_dir':'asc'}}])
#     >>> fields = [ek.TR_Field('tr.revenue'),ek.TR_Field('tr.open',None,'asc',1),ek.TR_Field('TR.GrossProfit',{'Scale': 6, 'Curn': 'EUR'},'asc',0)]
#     >>> data, err = ek.get_data(["IBM","MSFT.O"],fields)

# %%
fields = [
    'TR.TRESGScoreGrade',
    'TR.EnvironmentPillarScoreGrade',
    'TR.SocialPillarScoreGrade',
    'TR.GovernancePillarScoreGrade',
    'TR.AnalyticCO2ScoreGrade',
    'TR.TRESGInnovationScoreGrade',
    'TR.TRESGCSRStrategyScoreGrade',
    #'TR.TRESGCControversiesScore',
    #'TR.TRESGScoreGrade',
    #'TR.EnvironmentPillarScoreGrade',
    #'TR.SocialPillarScoreGrade',
    #'TR.GovernancePillarScoreGrade',
    #'TR.TRESGCControversiesScoreGrade',
   # 'TR.PolicyEmissions',
   # 'TR.TargetEmissions', # SBTi
   # 'TR.EmissionReductionTargetPctage', # SBTi
   # 'TR.CO2EstimationMethod', 
   # 'TR.EmissionReductionTargetYear', # SBTi
   # 'TR.PolicyEmissionsScore',
   # 'TR.TargetEmissionsScore',
   # 'TR.TRESGResourceUseScore',
   # 'TR.CO2EmissionTotal',
   # 'TR.CO2DirectScope1',
   # 'TR.CO2IndirectScope2',
   # 'TR.CO2IndirectScope3',
   # 'TR.AnalyticEstimatedCO2Total',
   # 'TR.AnalyticCO2',   
   # 'TR.EnergyUseTotal',
   # 'TR.AnalyticEnergyUse',
   # 'TR.TRESGInnovationScoreGrade',
    #'TR.TRESGCSRStrategyScoreGrade',
   # 'TR.EnergyUseScore',
]

environmental_fields = [
    'TR.EnvironmentPillarScoreGrade(SDate=0,EDate=-3,Period=FY0,Frq=FY).date',
    'TR.EnvironmentPillarScoreGrade(SDate=0,EDate=-3,Period=FY0,Frq=FY)',
    'TR.EnvironmentPillarScore(SDate=0,EDate=-3,Period=FY0,Frq=FY).date',
    'TR.EnvironmentPillarScore(SDate=0,EDate=-3,Period=FY0,Frq=FY)',
]

# %%
esg_df, err = ek.get_data(instruments = isins, fields=fields)

# %%
esg_df_bis, err = ek.get_data(instruments = isins, fields=environmental_fields)

# %% [markdown]
# #### Then, add the ESG data to the initial portfolio.

# %%
esg_df
# Out:
#       Instrument ESG Score Grade Environmental Pillar Score Grade  \
# 0   US4581401001               A                                A
# 1   US3886891015               B                               B+
# 2   US3453708600               A                               A+
# 3   US2435371073              B-                               B-
# 4   US0382221051              A-                               A-
# 5   US0394831020              A-                               A-
# 6   US0367521038              A-                               A-
# 7   US0200021014              A-                               A-
# 8   US00508Y1029              B-                                B
# 9   US1170431092              B+                               B-
# 10  US7310681025              A-                               B+
# 11  US4663131039              B+                               A-
# 12  US49338L1035              A-                               A-
# 13  US58933Y1055              A-                               A-
# 14  US5951121038              B+                                B
# 15  US6005441000              B+                               A-
# 16  US6558441084               B                               B+
# 17  US6937181088               B                               A-
# 18  JP3854600008               A                               A+
# 19  FR0000121329               B                                B
# 20  JP3404600003              B-                               B+
# 21  US8545021011              B+                               A+
# 22  CH0024638196              B-                                B
# 23  DE0005190003               A                               A+
# 24  DE0007100000              A+                               A+
# 25  DE000BASF111               A                                A
# 26  JP3634600005               B                               A-
# 27  FI0009005961               A                               A+
# 28  FR0000120628              A-                               B-
# 29  FR0010220475               A                               A+
# 30  FR0013176526              A-                               A-
# 31  GB00B1XZS820              A-                               A-
# 32  JP3249600002              B+                               B+
# 33  FR0000120578               A                                A
# 34  US8832031012              B+                               B+
#
#    Social Pillar Score Grade Governance Pillar Score Grade  \
# 0                          A                            A+
# 1                         C+                            B+
# 2                          A                             B
# 3                          B                            C+
# 4                         B+                            A-
# 5                         A-                             A
# 6                          A                            A-
# 7                         A-                            B+
# 8                         B-                             C
# 9                         B+                             A
# 10                         A                            A-
# 11                        B+                            A-
# 12                        A+                            C+
# 13                        A+                             B
# 14                        A-                            B+
# 15                        A+                            C-
# 16                        B-                            A-
# 17                        B-                             B
# 18                         A                             A
# 19                         B                            C+
# 20                        C+                             B
# 21                        A-                             C
# 22                        B-                             C
# 23                        A-                            A-
# 24                         A                            A+
# 25                        A+                            B+
# 26                        B-                            C+
# 27                         A                            B+
# 28                         A                             A
# 29                         A                            A-
# 30                        A-                             A
# 31                        A-                            B+
# 32                        B+                            B+
# 33                        A+                            A-
# 34                         B                             A
#
#    Environmental Innovation Score Grade CSR Strategy Score Grade
# 0                                    A-                       A+
# 1                                     C                       A+
# 2                                     A                       A+
# 3                                    D+                       B+
# 4                                    A-                       B+
# 5                                     A                       A+
# 6                                    D-                       B-
# 7                                    A-                       B+
# 8                                    B+                        B
# 9                                    C+                       A-
# 10                                   C+                       A-
# 11                                   A-                       C+
# 12                                   B+                       B+
# 13                                   D-                       A+
# 14                                    C                       B+
# 15                                    C                       B+
# 16                                   C+                       A-
# 17                                    A                       D+
# 18                                    A                        B
# 19                                    D                       A-
# 20                                   A-                        B
# 21                                   A+                        A
# 22                                   B-                       B+
# 23                                   A+                       B-
# 24                                   A+                       A+
# 25                                   A+                       A+
# 26                                    A                        B
# 27                                   A+                       B+
# 28                                   D+                       B-
# 29                                   A+                       A+
# 30                                   B+                       A-
# 31                                   D-                       A+
# 32                                   B+                       A-
# 33                                    D                       A-
# 34                                    A                        C

# %%
esg_df.columns
# Out:
# Index(['Instrument', 'ESG Score Grade', 'Environmental Pillar Score Grade',
#        'Social Pillar Score Grade', 'Governance Pillar Score Grade',
#        'Environmental Innovation Score Grade', 'CSR Strategy Score Grade'],
#       dtype='object')

# %%
#esg_df["Symbol"] = symbols
#esg_df["SEDOL"] = sedols
esg_df["company_isin"] = isins

# %%
portfolio_df = portfolio.copy()#iloc[:-12,:]

# %%
esg_df_bis["year"] = pd.to_datetime(esg_df_bis.Date.iloc[:,0]).dt.year

# %%
esg_df_bis = esg_df_bis.drop(columns=["Date"])

# %%
years = list(esg_df_bis.year.value_counts().index)
for year in years:
    esg_df = format_df(esg_df, esg_df_bis, year)

# %%
esg_df = esg_df.rename(columns={"Instrument":"ISIN"})

# %%
out = pd.merge(portfolio_df, esg_df, how="left", left_on="ISIN", right_on=["ISIN"])

# %%
out
# Out:
#           Date          ISIN                  instrument_name  Quantity  \
# 0   20/04/2021  US4581401001         INTEL CORP  COM USD0.001     32601
# 1   20/04/2021  US3886891015     GRAPHIC PACKAGING HOLDING CO     60000
# 2   20/04/2021  US3453708600                       FORD MOTOR     58492
# 3   20/04/2021  US2435371073         DECKERS OUTDOOR CORP COM      5200
# 4   20/04/2021  US0382221051            APPLIED MATERIALS NPV     14200
# 5   20/04/2021  US0394831020       ARCHER DANIELS MIDLAND NPV     55327
# 6   20/04/2021  US0367521038                ANTHEM INC UN USD      7198
# 7   20/04/2021  US0200021014                    ALLSTATE CORP      3286
# 8   20/04/2021  US00508Y1029                ACUITY BRANDS INC      8450
# 9   20/04/2021  US1170431092                        BRUNSWICK     19000
# 10  20/04/2021  US7310681025                     POLARIS INC.      5291
# 11  20/04/2021  US4663131039                    JABIL CIRCUIT     41840
# 12  20/04/2021  US49338L1035  KEYSIGHT TECHNOLOGIES IN UN USD     12253
# 13  20/04/2021  US58933Y1055                     MERCK AND CO     28036
# 14  20/04/2021  US5951121038   MICRON TECHNOLOGY  COM USD0.10     18072
# 15  20/04/2021  US6005441000                HERMAN MILLER INC     33916
# 16  20/04/2021  US6558441084      NORFOLK STHN CORP  COM USD1      5039
# 17  20/04/2021  US6937181088            PACCAR INC  COM USD12     12267
# 18  20/04/2021  JP3854600008            HONDA MOTOR CO  JPY50     24000
# 19  20/04/2021  FR0000121329                           THALES     26315
# 20  20/04/2021  JP3404600003             SUMITOMO CORP  JPY50    124200
# 21  20/04/2021  US8545021011         STANLEY  BLACK ET DECKER      8000
# 22  20/04/2021  CH0024638196             SCHINDLER HOLDING BP      6000
# 23  20/04/2021  DE0005190003                              BMW      7601
# 24  20/04/2021  DE0007100000                       DAIMLER AG      9464
# 25  20/04/2021  DE000BASF111                          BASF AG     11692
# 26  20/04/2021  JP3634600005           TOYOTA INDUSTRIES CORP      7800
# 27  20/04/2021  FI0009005961                  STORA ENSO AB R     97226
# 28  20/04/2021  FR0000120628                              AXA     95934
# 29  20/04/2021  FR0010220475                   ALSTOM REGROUP     48780
# 30  20/04/2021  FR0013176526                   VALEO DIVISION     18212
# 31  20/04/2021  GB00B1XZS820                   ANGLO AMERICAN     27940
# 32  20/04/2021  JP3249600002              KYOCERA CORP  JPY50     26800
# 33  20/04/2021  FR0000120578                   SANOFI-AVENTIS     23069
# 34  20/04/2021  US8832031012               TEXTRON INC US USD     22000
#
#     Valuation       Weight Asset Class                  Sector  \
# 0   2110914,8  0,019652104     Actions  Information Technology
# 1     1110600  0,010339416     Actions               Materials
# 2   709507,94  0,006605347     Actions  Consumer Discretionary
# 3     1773512  0,016510965     Actions  Consumer Discretionary
# 4     1898966  0,017678913     Actions  Information Technology
# 5   3289190,2   0,03062156     Actions        Consumer Staples
# 6   2703712,8   0,02517091     Actions             Health Care
# 7    401549,2  0,003738325     Actions              Financials
# 8   1447400,5  0,013474947     Actions             Industrials
# 9     1996330  0,018585347     Actions  Consumer Discretionary
# 10   767300,8  0,007143384     Actions  Consumer Discretionary
# 11  2277769,5  0,021205481     Actions  Information Technology
# 12    1752424  0,016314643     Actions  Information Technology
# 13    2171949  0,020220317     Actions             Health Care
# 14  1638407,5  0,015253176     Actions  Information Technology
# 15  1502478,8  0,013987713     Actions             Industrials
# 16  1364863,5  0,012706548     Actions             Industrials
# 17  1164383,6  0,010840128     Actions             Industrials
# 18  738868,75  0,006878688     Actions  Consumer Discretionary
# 19  2723678,2  0,025356783     Actions             Industrials
# 20  1761730,5  0,016401282     Actions             Industrials
# 21    1643040  0,015296303     Actions             Industrials
# 22  1866036,2  0,017372344     Actions             Industrials
# 23   798562,7  0,007434425     Actions  Consumer Discretionary
# 24   861188,8  0,008017458     Actions  Consumer Discretionary
# 25  1005101,5  0,009357251     Actions               Materials
# 26  688140,44   0,00640642     Actions  Consumer Discretionary
# 27  1951486,5  0,018167865     Actions               Materials
# 28  2729448,2    0,0254105     Actions              Financials
# 29    2623192   0,02442128     Actions             Industrials
# 30  599532,94  0,005581506     Actions  Consumer Discretionary
# 31  1230410,6  0,011454824     Actions               Materials
# 32  1785845,8   0,01662579     Actions  Information Technology
# 33  2382457,2  0,022180097     Actions             Health Care
# 34    1287880   0,01198985     Actions             Industrials
#
#                                 Subsector Country  ...  \
# 0                          Semiconductors     USA  ...
# 1                         Paper Packaging     USA  ...
# 2                Automobile Manufacturers     USA  ...
# 3                                Footwear     USA  ...
# 4                 Semiconductor Equipment     USA  ...
# 5                   Agricultural Products     USA  ...
# 6                     Managed Health Care     USA  ...
# 7           Property & Casualty Insurance     USA  ...
# 8       Electrical Components & Equipment     USA  ...
# 9                        Leisure Products     USA  ...
# 10                       Leisure Products     USA  ...
# 11      Electronic Manufacturing Services     USA  ...
# 12     Electronic Equipment & Instruments     USA  ...
# 13                        Pharmaceuticals     USA  ...
# 14                         Semiconductors     USA  ...
# 15             Office Services & Supplies     USA  ...
# 16                              Railroads     USA  ...
# 17  Construction Machinery & Heavy Trucks     USA  ...
# 18               Automobile Manufacturers     JPN  ...
# 19                    Aerospace & Defense     FRA  ...
# 20       Trading Companies & Distributors     JPN  ...
# 21                   Industrial Machinery     USA  ...
# 22                   Industrial Machinery     CHE  ...
# 23               Automobile Manufacturers     DEU  ...
# 24               Automobile Manufacturers     DEU  ...
# 25                  Diversified Chemicals     DEU  ...
# 26                 Auto Parts & Equipment     JPN  ...
# 27                         Paper Products     FIN  ...
# 28                   Multi-Line Insurance     FRA  ...
# 29  Construction Machinery & Heavy Trucks     FRA  ...
# 30                 Auto Parts & Equipment     FRA  ...
# 31            Diversified Metals & Mining     ZAF  ...
# 32                  Electronic Components     JPN  ...
# 33                        Pharmaceuticals     FRA  ...
# 34                    Aerospace & Defense     USA  ...
#
#    Environmental Pillar Score Grade 2017 Environmental Pillar Score 2017  \
# 0                                      A                       91.441327
# 1                                     B-                       56.839967
# 2                                      A                       85.528925
# 3                                     C+                       42.787524
# 4                                     B+                       71.361961
# 5                                     A-                       76.834243
# 6                                     B+                       74.219858
# 7                                     A-                       82.377392
# 8                                      C                       37.228769
# 9                                     D+                       22.727273
# 10                                     B                       62.370130
# 11                                     B                       65.309611
# 12                                    A-                       77.786703
# 13                                    B+                       74.142122
# 14                                    B-                       53.424745
# 15                                    A-                       78.086397
# 16                                    A-                       80.360685
# 17                                    A-                       78.474122
# 18                                     A                       85.870030
# 19                                     B                       64.372582
# 20                                     B                       61.488095
# 21                                     C                       41.603911
# 22                                    B-                       55.659254
# 23                                    A+                       96.259147
# 24                                    A+                       92.747684
# 25                                     A                       89.532035
# 26                                     A                       84.912209
# 27                                     A                       91.425770
# 28                                    B-                       55.428707
# 29                                    A+                       95.560428
# 30                                    A-                       77.519340
# 31                                     A                       86.316656
# 32                                    B+                       72.390330
# 33                                     A                       84.314945
# 34                                    C-                       28.867263
#
#    Environmental Pillar Score Grade 2019 Environmental Pillar Score 2019  \
# 0                                      A                       90.112512
# 1                                     B+                       71.735113
# 2                                     A+                       92.032877
# 3                                     C+                       47.280020
# 4                                     A-                       79.300546
# 5                                     A-                       79.523350
# 6                                     A-                       80.521592
# 7                                     A-                       79.098106
# 8                                      B                       59.847476
# 9                                     B-                       50.879765
# 10                                    B+                       73.753666
# 11                                    A-                       76.084592
# 12                                    A-                       78.676397
# 13                                    A-                       80.462679
# 14                                     B                       59.469187
# 15                                  <NA>                             NaN
# 16                                    B+                       72.134833
# 17                                    A-                       78.329280
# 18                                     A                       90.886698
# 19                                     B                       64.456358
# 20                                    B+                       66.716792
# 21                                    A+                       93.994177
# 22                                     B                       61.891525
# 23                                    A+                       98.249516
# 24                                    A+                       96.624395
# 25                                     A                       90.130533
# 26                                     A                       85.017090
# 27                                    A+                       92.807214
# 28                                    B-                       50.345589
# 29                                    A+                       96.008017
# 30                                    A-                       79.151321
# 31                                    A-                       82.859774
# 32                                    B+                       74.424920
# 33                                     A                       84.217669
# 34                                  <NA>                             NaN
#
#    Environmental Pillar Score Grade 2016 Environmental Pillar Score 2016  \
# 0                                      A                       90.726723
# 1                                     C-                       27.555011
# 2                                      A                       86.101393
# 3                                   <NA>                             NaN
# 4                                     B+                       68.962486
# 5                                     B-                       55.015445
# 6                                     B+                       67.169059
# 7                                     A-                       83.022599
# 8                                   <NA>                             NaN
# 9                                     D+                       22.727273
# 10                                    B-                       55.235390
# 11                                    B+                       68.336004
# 12                                    A-                       75.847335
# 13                                    B+                       73.255677
# 14                                    B-                       53.224496
# 15                                    A-                       78.700369
# 16                                    A-                       77.907913
# 17                                    A-                       76.784386
# 18                                  <NA>                             NaN
# 19                                     B                       60.806491
# 20                                     B                       63.288497
# 21                                     C                       37.842345
# 22                                    B-                       57.074994
# 23                                  <NA>                             NaN
# 24                                     A                       87.459260
# 25                                     A                       87.865260
# 26                                  <NA>                             NaN
# 27                                     A                       90.215546
# 28                                    B-                       55.473804
# 29                                  <NA>                             NaN
# 30                                    A-                       75.433382
# 31                                     A                       86.480864
# 32                                    B+                       73.242799
# 33                                     A                       85.917261
# 34                                    C-                       25.724906
#
#    Environmental Pillar Score Grade 2020 Environmental Pillar Score 2020  \
# 0                                   <NA>                             NaN
# 1                                   <NA>                             NaN
# 2                                   <NA>                             NaN
# 3                                     B-                       55.789356
# 4                                   <NA>                             NaN
# 5                                   <NA>                             NaN
# 6                                   <NA>                             NaN
# 7                                   <NA>                             NaN
# 8                                      B                       61.373732
# 9                                   <NA>                             NaN
# 10                                  <NA>                             NaN
# 11                                  <NA>                             NaN
# 12                                  <NA>                             NaN
# 13                                  <NA>                             NaN
# 14                                  <NA>                             NaN
# 15                                  <NA>                             NaN
# 16                                  <NA>                             NaN
# 17                                  <NA>                             NaN
# 18                                    A+                       91.852794
# 19                                  <NA>                             NaN
# 20                                  <NA>                             NaN
# 21                                  <NA>                             NaN
# 22                                  <NA>                             NaN
# 23                                    A+                       95.603423
# 24                                  <NA>                             NaN
# 25                                  <NA>                             NaN
# 26                                    A-                       81.057761
# 27                                  <NA>                             NaN
# 28                                  <NA>                             NaN
# 29                                    A+                       98.714771
# 30                                  <NA>                             NaN
# 31                                  <NA>                             NaN
# 32                                  <NA>                             NaN
# 33                                  <NA>                             NaN
# 34                                    B+                       68.205044
#
#    Environmental Pillar Score Grade 2015  Environmental Pillar Score 2015
# 0                                   <NA>                              NaN
# 1                                   <NA>                              NaN
# 2                                   <NA>                              NaN
# 3                                   <NA>                              NaN
# 4                                   <NA>                              NaN
# 5                                   <NA>                              NaN
# 6                                   <NA>                              NaN
# 7                                   <NA>                              NaN
# 8                                   <NA>                              NaN
# 9                                   <NA>                              NaN
# 10                                  <NA>                              NaN
# 11                                  <NA>                              NaN
# 12                                  <NA>                              NaN
# 13                                  <NA>                              NaN
# 14                                  <NA>                              NaN
# 15                                    A-                        75.730633
# 16                                  <NA>                              NaN
# 17                                  <NA>                              NaN
# 18                                  <NA>                              NaN
# 19                                  <NA>                              NaN
# 20                                  <NA>                              NaN
# 21                                  <NA>                              NaN
# 22                                  <NA>                              NaN
# 23                                  <NA>                              NaN
# 24                                  <NA>                              NaN
# 25                                  <NA>                              NaN
# 26                                  <NA>                              NaN
# 27                                  <NA>                              NaN
# 28                                  <NA>                              NaN
# 29                                  <NA>                              NaN
# 30                                  <NA>                              NaN
# 31                                  <NA>                              NaN
# 32                                  <NA>                              NaN
# 33                                  <NA>                              NaN
# 34                                  <NA>                              NaN
#
# [35 rows x 30 columns]

# %%
out.columns
# Out:
# Index(['Date', 'ISIN', 'instrument_name', 'Quantity', 'Valuation', 'Weight',
#        'Asset Class', 'Sector', 'Subsector', 'Country', 'Sleeve',
#        'ESG Score Grade', 'Environmental Pillar Score Grade',
#        'Social Pillar Score Grade', 'Governance Pillar Score Grade',
#        'Environmental Innovation Score Grade', 'CSR Strategy Score Grade',
#        'company_isin', 'Environmental Pillar Score Grade 2018',
#        'Environmental Pillar Score 2018',
#        'Environmental Pillar Score Grade 2017',
#        'Environmental Pillar Score 2017',
#        'Environmental Pillar Score Grade 2019',
#        'Environmental Pillar Score 2019',
#        'Environmental Pillar Score Grade 2016',
#        'Environmental Pillar Score 2016',
#        'Environmental Pillar Score Grade 2020',
#        'Environmental Pillar Score 2020',
#        'Environmental Pillar Score Grade 2015',
#        'Environmental Pillar Score 2015'],
#       dtype='object')

# %%
out.to_csv(output_path+"portfolio_210421.csv")
